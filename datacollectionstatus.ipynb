# %% [markdown]
# job_roles = {
#     "Software Engineer": None,
#     "QA tester or engineer": None,
#     "Computer Programmer": None,
#     "Software Architect": None,
#     "Network Engineer": None,
#     "Network Administrator": None,
#     "Systems Administrator": None,
#     "Project Coordinator": None,
#     "Desk Analyst": None,
#     "Database Developer": None,
#     "Database Administrator": None,
#     "Data Analyst": None,
#     "Data Scientist": None,
#     "DevOps Engineer": None,
#     "Front-End Developer": None,
#     "Back-End Developer": None,
#     "Full-Stack Developer": None,
#     "Cloud Solutions Architect": None,
#     "IT Support Specialist": None,
#     "Cybersecurity Analyst": None,
#     "Mobile Application Developer": None,
#     "IT Technician": None,
#     "Information Security Analyst": None,
#     "IT Auditor": None,
#     "Web Developer": None,
#     "UX Designer": None,
#     "Robotics Engineer": None,
#     "IT Project Manager": None,
#     "IT Manager": None,
#     "Business Systems Analyst": None,
#     "Software application packager": None,
#     "Development operations engineer": None,
#     "Analytics manager": None,
#     "Game developer": None,
#     "Hardware engineer": None,
#     "Cloud Product and Project Manager": None,
#     "Information Systems Security Manager": None,
#     "Application Development Manager": None,
#     "React Developer": None,
#     "AI Developer": None,
#     "Graphic Designer": None,
#     "UI Designer": None,
#     "Data Modeler": None,
#     "Agile Project Manager": None,
#     "Digital Marketing Specialist": None,
#     "Ethical Hacker": None,
#     "Site Reliability Engineer": None,
#     "Google Analytics": None,
#     "python developer": None,
#     "Technical Team Leader": None
# }

# %%
# started ,progressing ,completed
job_roles = {
    "Software Engineer":'progressing',
    "QA tester or engineer": None,
    "Computer Programmer": None,
    "Software Architect": None,
    "Network Engineer": None,
    "Network Administrator": None,
    "Systems Administrator": None,
    "Project Coordinator": None,
    "Desk Analyst": None,
    "Database Developer": None,
    "Database Administrator": None,
    "Data Analyst": None,
    "Data Scientist": None,
    "DevOps Engineer": None,
    "Front-End Developer": None,
    "Back-End Developer": None,
    "Full-Stack Developer": None,
    "Cloud Solutions Architect": None,
    "IT Support Specialist": None,
    "Cybersecurity Analyst": None,
    "Mobile Application Developer": None,
    "IT Technician": None,
    "Information Security Analyst": None,
    "IT Auditor": None,
    "Web Developer": None,
    "UX Designer": None,
    "Robotics Engineer": None,
    "IT Project Manager": None,
    "IT Manager": None,
    "Business Systems Analyst": None,
    "Software application packager": None,
    "Development operations engineer": None,
    "Analytics manager": None,
    "Game developer": None,
    "Hardware engineer": None,
    "Cloud Product and Project Manager": None,
    "Information Systems Security Manager": None,
    "Application Development Manager": None,
    "React Developer": None,
    "AI Developer": None,
    "Graphic Designer": None,
    "UI Designer": None,
    "Data Modeler": None,
    "Agile Project Manager": None,
    "Digital Marketing Specialist": None,
    "Ethical Hacker": None,
    "Site Reliability Engineer": None,
    "Google Analytics": None,
    "python developer": None,
    "Technical Team Leader": None
}
